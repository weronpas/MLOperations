# %% [markdown]
# # Example 1 - OpenWeatherMap API — Real Sensor-like Weather Data
#
# Provides near real-time data for temperature, humidity, wind speed, air pressure, etc.
#
# Perfect for demonstrating regression or drift adaptation tasks (e.g., predicting next-hour temperature, energy consumption, etc.).
#
# Free tier with public API key.

# %%
import requests, time
from river import linear_model, optim, preprocessing, metrics

model = preprocessing.StandardScaler() | linear_model.LinearRegression(
    optimizer=optim.SGD(0.01)
)
mae = metrics.MAE()

URL = "https://api.open-meteo.com/v1/forecast?latitude=48.85&longitude=2.35&current_weather=true"

try:
    while True:
        data = requests.get(URL).json()["current_weather"]
        temp = data["temperature"]
        wind = data["windspeed"]

        x = {"wind": wind}
        y = temp

        y_pred = model.predict_one(x)
        model.learn_one(x, y)
        mae.update(y, y_pred)

        print(f"Temp={y:.2f}°C | Wind={wind:.1f} km/h | Pred={y_pred:.2f}°C | MAE={mae.get():.3f}")
        time.sleep(2)  # 5 min delay
except KeyboardInterrupt:
    print("\nStopped streaming.")
# Out:
# Temp=16.50°C | Wind=9.4 km/h | Pred=0.00°C | MAE=16.500
# Temp=16.50°C | Wind=9.4 km/h | Pred=0.33°C | MAE=16.335
# Temp=16.50°C | Wind=9.4 km/h | Pred=0.65°C | MAE=16.172
# Temp=16.50°C | Wind=9.4 km/h | Pred=0.97°C | MAE=16.012
# Temp=16.50°C | Wind=9.4 km/h | Pred=1.28°C | MAE=15.853
# Temp=16.50°C | Wind=9.4 km/h | Pred=1.59°C | MAE=15.697
# Temp=16.50°C | Wind=9.4 km/h | Pred=1.88°C | MAE=15.542
# Temp=16.50°C | Wind=9.4 km/h | Pred=2.18°C | MAE=15.390
# Temp=16.50°C | Wind=9.4 km/h | Pred=2.46°C | MAE=15.240
# Temp=16.50°C | Wind=9.4 km/h | Pred=2.74°C | MAE=15.091
# Temp=16.50°C | Wind=9.4 km/h | Pred=3.02°C | MAE=14.945
# Temp=16.50°C | Wind=9.4 km/h | Pred=3.29°C | MAE=14.801
# Temp=16.50°C | Wind=9.4 km/h | Pred=3.55°C | MAE=14.658
# Temp=16.50°C | Wind=9.4 km/h | Pred=3.81°C | MAE=14.518
# Temp=16.50°C | Wind=9.4 km/h | Pred=4.06°C | MAE=14.379
# Temp=16.50°C | Wind=9.4 km/h | Pred=4.31°C | MAE=14.242
# Temp=16.50°C | Wind=9.4 km/h | Pred=4.56°C | MAE=14.106
# Temp=16.50°C | Wind=9.4 km/h | Pred=4.80°C | MAE=13.973
# Temp=16.50°C | Wind=9.4 km/h | Pred=5.03°C | MAE=13.841
# Temp=16.50°C | Wind=9.4 km/h | Pred=5.26°C | MAE=13.711
# Temp=16.50°C | Wind=9.4 km/h | Pred=5.48°C | MAE=13.583
# Temp=16.50°C | Wind=9.4 km/h | Pred=5.70°C | MAE=13.456
# Temp=16.50°C | Wind=9.4 km/h | Pred=5.92°C | MAE=13.331
# Temp=16.50°C | Wind=9.4 km/h | Pred=6.13°C | MAE=13.208
# Temp=16.50°C | Wind=9.4 km/h | Pred=6.34°C | MAE=13.086
# Temp=16.50°C | Wind=9.4 km/h | Pred=6.54°C | MAE=12.965
# Temp=16.50°C | Wind=9.4 km/h | Pred=6.74°C | MAE=12.847
# Temp=16.50°C | Wind=9.4 km/h | Pred=6.94°C | MAE=12.729
# Temp=16.50°C | Wind=9.4 km/h | Pred=7.13°C | MAE=12.613
# Temp=16.50°C | Wind=9.4 km/h | Pred=7.32°C | MAE=12.499
# Temp=16.50°C | Wind=9.4 km/h | Pred=7.50°C | MAE=12.386
# Temp=16.50°C | Wind=9.4 km/h | Pred=7.68°C | MAE=12.275
# Temp=16.50°C | Wind=9.4 km/h | Pred=7.86°C | MAE=12.165
# Temp=16.50°C | Wind=9.4 km/h | Pred=8.03°C | MAE=12.056
# Temp=16.50°C | Wind=9.4 km/h | Pred=8.20°C | MAE=11.949
# Temp=16.50°C | Wind=9.4 km/h | Pred=8.36°C | MAE=11.843
# Temp=16.50°C | Wind=9.4 km/h | Pred=8.53°C | MAE=11.738
# Temp=16.50°C | Wind=9.4 km/h | Pred=8.69°C | MAE=11.635
# Temp=16.50°C | Wind=9.4 km/h | Pred=8.84°C | MAE=11.533
# Temp=16.50°C | Wind=9.4 km/h | Pred=9.00°C | MAE=11.432
# Temp=16.50°C | Wind=9.4 km/h | Pred=9.15°C | MAE=11.333
# Temp=16.50°C | Wind=9.4 km/h | Pred=9.29°C | MAE=11.235
# Temp=16.50°C | Wind=9.4 km/h | Pred=9.44°C | MAE=11.138
# Temp=16.50°C | Wind=9.4 km/h | Pred=9.58°C | MAE=11.042
# Temp=16.50°C | Wind=9.4 km/h | Pred=9.72°C | MAE=10.947
# Temp=16.50°C | Wind=9.4 km/h | Pred=9.85°C | MAE=10.854
# Temp=16.50°C | Wind=9.4 km/h | Pred=9.99°C | MAE=10.761
# Temp=16.50°C | Wind=9.4 km/h | Pred=10.12°C | MAE=10.670
# Temp=16.50°C | Wind=9.4 km/h | Pred=10.24°C | MAE=10.580
# Temp=16.50°C | Wind=9.4 km/h | Pred=10.37°C | MAE=10.491
# Temp=16.50°C | Wind=9.4 km/h | Pred=10.49°C | MAE=10.403
# Temp=16.50°C | Wind=9.4 km/h | Pred=10.61°C | MAE=10.316
# Temp=16.50°C | Wind=9.4 km/h | Pred=10.73°C | MAE=10.231
# Temp=16.50°C | Wind=9.4 km/h | Pred=10.84°C | MAE=10.146
# Temp=16.50°C | Wind=9.4 km/h | Pred=10.96°C | MAE=10.062
# Temp=16.50°C | Wind=9.4 km/h | Pred=11.07°C | MAE=9.980
# Temp=16.50°C | Wind=9.4 km/h | Pred=11.18°C | MAE=9.898
# Temp=16.50°C | Wind=9.4 km/h | Pred=11.28°C | MAE=9.817
# Temp=16.50°C | Wind=9.4 km/h | Pred=11.39°C | MAE=9.737
# Temp=16.50°C | Wind=9.4 km/h | Pred=11.49°C | MAE=9.659
# Temp=16.50°C | Wind=9.4 km/h | Pred=11.59°C | MAE=9.581
# Temp=16.50°C | Wind=9.4 km/h | Pred=11.69°C | MAE=9.504
# Temp=16.50°C | Wind=9.4 km/h | Pred=11.78°C | MAE=9.428
# Temp=16.50°C | Wind=9.4 km/h | Pred=11.88°C | MAE=9.353
# Temp=16.50°C | Wind=9.4 km/h | Pred=11.97°C | MAE=9.279
# Temp=16.50°C | Wind=9.4 km/h | Pred=12.06°C | MAE=9.205
# Temp=16.50°C | Wind=9.4 km/h | Pred=12.15°C | MAE=9.133
# Temp=16.50°C | Wind=9.4 km/h | Pred=12.24°C | MAE=9.061
# Temp=16.50°C | Wind=9.4 km/h | Pred=12.32°C | MAE=8.990
# Temp=16.50°C | Wind=9.4 km/h | Pred=12.41°C | MAE=8.920
# Temp=16.50°C | Wind=9.4 km/h | Pred=12.49°C | MAE=8.851
# Temp=16.50°C | Wind=9.4 km/h | Pred=12.57°C | MAE=8.783
# Temp=16.50°C | Wind=9.4 km/h | Pred=12.65°C | MAE=8.715
# Temp=16.50°C | Wind=9.4 km/h | Pred=12.72°C | MAE=8.649
# Temp=16.50°C | Wind=9.4 km/h | Pred=12.80°C | MAE=8.583
# Temp=16.50°C | Wind=9.4 km/h | Pred=12.87°C | MAE=8.517
# Temp=16.50°C | Wind=9.4 km/h | Pred=12.95°C | MAE=8.453
# Temp=16.50°C | Wind=9.4 km/h | Pred=13.02°C | MAE=8.389
# Temp=16.50°C | Wind=9.4 km/h | Pred=13.09°C | MAE=8.326
# Temp=16.50°C | Wind=9.4 km/h | Pred=13.16°C | MAE=8.264
# Temp=16.50°C | Wind=9.4 km/h | Pred=13.22°C | MAE=8.202
# Temp=16.50°C | Wind=9.4 km/h | Pred=13.29°C | MAE=8.142
# Temp=16.50°C | Wind=9.4 km/h | Pred=13.35°C | MAE=8.081
# Temp=16.50°C | Wind=9.4 km/h | Pred=13.42°C | MAE=8.022
# Temp=16.50°C | Wind=9.4 km/h | Pred=13.48°C | MAE=7.963
# Temp=16.50°C | Wind=9.4 km/h | Pred=13.54°C | MAE=7.905
# Temp=16.50°C | Wind=9.4 km/h | Pred=13.60°C | MAE=7.847
# Temp=16.50°C | Wind=9.4 km/h | Pred=13.65°C | MAE=7.791
# Temp=16.50°C | Wind=9.4 km/h | Pred=13.71°C | MAE=7.734
# Temp=16.50°C | Wind=9.4 km/h | Pred=13.77°C | MAE=7.679
# Temp=16.50°C | Wind=9.4 km/h | Pred=13.82°C | MAE=7.624
# Temp=16.50°C | Wind=9.4 km/h | Pred=13.88°C | MAE=7.570
# Temp=16.50°C | Wind=9.4 km/h | Pred=13.93°C | MAE=7.516
# Temp=16.50°C | Wind=9.4 km/h | Pred=13.98°C | MAE=7.463
# Temp=16.50°C | Wind=9.4 km/h | Pred=14.03°C | MAE=7.410
# Temp=16.50°C | Wind=9.4 km/h | Pred=14.08°C | MAE=7.358
# Temp=16.50°C | Wind=9.4 km/h | Pred=14.13°C | MAE=7.307
# Temp=16.50°C | Wind=9.4 km/h | Pred=14.18°C | MAE=7.256
# Temp=16.50°C | Wind=9.4 km/h | Pred=14.22°C | MAE=7.206
# Temp=16.50°C | Wind=9.4 km/h | Pred=14.27°C | MAE=7.156
# Temp=16.50°C | Wind=9.4 km/h | Pred=14.31°C | MAE=7.107
# Temp=16.50°C | Wind=9.4 km/h | Pred=14.36°C | MAE=7.058
# Temp=16.50°C | Wind=9.4 km/h | Pred=14.40°C | MAE=7.010
# Temp=16.50°C | Wind=9.4 km/h | Pred=14.44°C | MAE=6.962
# Temp=16.50°C | Wind=9.4 km/h | Pred=14.48°C | MAE=6.915
# Temp=16.50°C | Wind=9.4 km/h | Pred=14.52°C | MAE=6.869
# Temp=16.50°C | Wind=9.4 km/h | Pred=14.56°C | MAE=6.823
# Temp=16.50°C | Wind=9.4 km/h | Pred=14.60°C | MAE=6.777
# Temp=16.50°C | Wind=9.4 km/h | Pred=14.64°C | MAE=6.732
# Temp=16.50°C | Wind=9.4 km/h | Pred=14.68°C | MAE=6.687
# Temp=16.50°C | Wind=9.4 km/h | Pred=14.71°C | MAE=6.643
# Temp=16.50°C | Wind=9.4 km/h | Pred=14.75°C | MAE=6.599
# Temp=16.50°C | Wind=9.4 km/h | Pred=14.78°C | MAE=6.556
# Temp=16.50°C | Wind=9.4 km/h | Pred=14.82°C | MAE=6.514
# Temp=16.50°C | Wind=9.4 km/h | Pred=14.85°C | MAE=6.471
# Temp=16.50°C | Wind=9.4 km/h | Pred=14.88°C | MAE=6.429
# Temp=16.50°C | Wind=9.4 km/h | Pred=14.92°C | MAE=6.388
# Temp=16.50°C | Wind=9.4 km/h | Pred=14.95°C | MAE=6.347
# Temp=16.50°C | Wind=9.4 km/h | Pred=14.98°C | MAE=6.306
# Temp=16.50°C | Wind=9.4 km/h | Pred=15.01°C | MAE=6.266
# Temp=16.50°C | Wind=9.4 km/h | Pred=15.04°C | MAE=6.227
# Temp=16.50°C | Wind=9.4 km/h | Pred=15.07°C | MAE=6.187
# Temp=16.50°C | Wind=9.4 km/h | Pred=15.10°C | MAE=6.148
# Temp=16.50°C | Wind=9.4 km/h | Pred=15.13°C | MAE=6.110
# Temp=16.50°C | Wind=9.4 km/h | Pred=15.15°C | MAE=6.072
# Temp=16.50°C | Wind=9.4 km/h | Pred=15.18°C | MAE=6.034
# Temp=16.50°C | Wind=9.4 km/h | Pred=15.21°C | MAE=5.997
# Temp=16.50°C | Wind=9.4 km/h | Pred=15.23°C | MAE=5.960
# Temp=16.50°C | Wind=9.4 km/h | Pred=15.26°C | MAE=5.923
# Temp=16.50°C | Wind=9.4 km/h | Pred=15.28°C | MAE=5.887
# Temp=16.50°C | Wind=9.4 km/h | Pred=15.31°C | MAE=5.851
# Temp=16.50°C | Wind=9.4 km/h | Pred=15.33°C | MAE=5.816
# Temp=16.50°C | Wind=9.4 km/h | Pred=15.35°C | MAE=5.781
# Temp=16.50°C | Wind=9.4 km/h | Pred=15.38°C | MAE=5.746
# Temp=16.50°C | Wind=9.4 km/h | Pred=15.40°C | MAE=5.711
# Temp=16.50°C | Wind=9.4 km/h | Pred=15.42°C | MAE=5.677
# Temp=16.50°C | Wind=9.4 km/h | Pred=15.44°C | MAE=5.644
# Temp=16.50°C | Wind=9.4 km/h | Pred=15.46°C | MAE=5.610
# Temp=16.50°C | Wind=9.4 km/h | Pred=15.48°C | MAE=5.577
# Temp=16.50°C | Wind=9.4 km/h | Pred=15.50°C | MAE=5.545
# Temp=16.50°C | Wind=9.4 km/h | Pred=15.52°C | MAE=5.512
# Temp=16.50°C | Wind=9.4 km/h | Pred=15.54°C | MAE=5.480
# Temp=16.50°C | Wind=9.4 km/h | Pred=15.56°C | MAE=5.448
# Temp=16.50°C | Wind=9.4 km/h | Pred=15.58°C | MAE=5.417
# Temp=16.50°C | Wind=9.4 km/h | Pred=15.60°C | MAE=5.386
# Temp=16.50°C | Wind=9.4 km/h | Pred=15.62°C | MAE=5.355
# Temp=16.50°C | Wind=9.4 km/h | Pred=15.64°C | MAE=5.324
# Temp=16.50°C | Wind=9.4 km/h | Pred=15.65°C | MAE=5.294
# Temp=16.50°C | Wind=9.4 km/h | Pred=15.67°C | MAE=5.264
# Temp=16.50°C | Wind=9.4 km/h | Pred=15.69°C | MAE=5.234
# Temp=16.50°C | Wind=9.4 km/h | Pred=15.70°C | MAE=5.205
# Temp=16.50°C | Wind=9.4 km/h | Pred=15.72°C | MAE=5.176
# Temp=16.50°C | Wind=9.4 km/h | Pred=15.73°C | MAE=5.147
# Temp=16.50°C | Wind=9.4 km/h | Pred=15.75°C | MAE=5.118
# Temp=16.50°C | Wind=9.4 km/h | Pred=15.76°C | MAE=5.090
# Temp=16.50°C | Wind=9.4 km/h | Pred=15.78°C | MAE=5.062
# Temp=16.50°C | Wind=9.4 km/h | Pred=15.79°C | MAE=5.034
# Temp=16.50°C | Wind=9.4 km/h | Pred=15.81°C | MAE=5.007
# Temp=16.50°C | Wind=9.4 km/h | Pred=15.82°C | MAE=4.980
# Temp=16.50°C | Wind=9.4 km/h | Pred=15.84°C | MAE=4.953
# Temp=16.50°C | Wind=9.4 km/h | Pred=15.85°C | MAE=4.926
# Temp=16.50°C | Wind=9.4 km/h | Pred=15.86°C | MAE=4.900
# Temp=16.50°C | Wind=9.4 km/h | Pred=15.87°C | MAE=4.873
# Temp=16.50°C | Wind=9.4 km/h | Pred=15.89°C | MAE=4.847
# Temp=16.50°C | Wind=9.4 km/h | Pred=15.90°C | MAE=4.822
# Temp=16.50°C | Wind=9.4 km/h | Pred=15.91°C | MAE=4.796
# Temp=16.50°C | Wind=9.4 km/h | Pred=15.92°C | MAE=4.771
# Temp=16.50°C | Wind=9.4 km/h | Pred=15.93°C | MAE=4.746
# Temp=16.50°C | Wind=9.4 km/h | Pred=15.95°C | MAE=4.721
# Temp=16.50°C | Wind=9.4 km/h | Pred=15.96°C | MAE=4.696
# Temp=16.50°C | Wind=9.4 km/h | Pred=15.97°C | MAE=4.672
# Temp=16.50°C | Wind=9.4 km/h | Pred=15.98°C | MAE=4.648
# Temp=16.50°C | Wind=9.4 km/h | Pred=15.99°C | MAE=4.624
# Temp=16.50°C | Wind=9.4 km/h | Pred=16.00°C | MAE=4.600
# Temp=16.50°C | Wind=9.4 km/h | Pred=16.01°C | MAE=4.577
# Temp=16.50°C | Wind=9.4 km/h | Pred=16.02°C | MAE=4.554
# Temp=16.50°C | Wind=9.4 km/h | Pred=16.03°C | MAE=4.531
# Temp=16.50°C | Wind=9.4 km/h | Pred=16.04°C | MAE=4.508
# Temp=16.50°C | Wind=9.4 km/h | Pred=16.05°C | MAE=4.485
# Temp=16.50°C | Wind=9.4 km/h | Pred=16.06°C | MAE=4.463
# Temp=16.50°C | Wind=9.4 km/h | Pred=16.07°C | MAE=4.440
# Temp=16.50°C | Wind=9.4 km/h | Pred=16.07°C | MAE=4.418
# Temp=16.50°C | Wind=9.4 km/h | Pred=16.08°C | MAE=4.396
# Temp=16.50°C | Wind=9.4 km/h | Pred=16.09°C | MAE=4.375
# Temp=16.50°C | Wind=9.4 km/h | Pred=16.10°C | MAE=4.353
# Temp=16.50°C | Wind=9.4 km/h | Pred=16.11°C | MAE=4.332
# Temp=16.50°C | Wind=9.4 km/h | Pred=16.11°C | MAE=4.311
# Temp=16.50°C | Wind=9.4 km/h | Pred=16.12°C | MAE=4.290
# Temp=16.50°C | Wind=9.4 km/h | Pred=16.13°C | MAE=4.269
# Temp=16.50°C | Wind=9.4 km/h | Pred=16.14°C | MAE=4.249
# Temp=16.50°C | Wind=9.4 km/h | Pred=16.14°C | MAE=4.228
# Temp=16.50°C | Wind=9.4 km/h | Pred=16.15°C | MAE=4.208
# Temp=16.50°C | Wind=9.4 km/h | Pred=16.16°C | MAE=4.188
# Temp=16.50°C | Wind=9.4 km/h | Pred=16.17°C | MAE=4.168
# Temp=16.50°C | Wind=9.4 km/h | Pred=16.17°C | MAE=4.148
# Temp=16.50°C | Wind=9.4 km/h | Pred=16.18°C | MAE=4.129
# Temp=16.50°C | Wind=9.4 km/h | Pred=16.19°C | MAE=4.110
# Temp=16.50°C | Wind=9.4 km/h | Pred=16.19°C | MAE=4.090
# Temp=16.50°C | Wind=9.4 km/h | Pred=16.20°C | MAE=4.071
# Temp=16.50°C | Wind=9.4 km/h | Pred=16.20°C | MAE=4.052
# Temp=16.50°C | Wind=9.4 km/h | Pred=16.21°C | MAE=4.034
# Temp=16.50°C | Wind=9.4 km/h | Pred=16.22°C | MAE=4.015
# Temp=16.50°C | Wind=9.4 km/h | Pred=16.22°C | MAE=3.997
# Temp=16.50°C | Wind=9.4 km/h | Pred=16.23°C | MAE=3.979
# Temp=16.50°C | Wind=9.4 km/h | Pred=16.23°C | MAE=3.960
# Temp=16.50°C | Wind=9.4 km/h | Pred=16.24°C | MAE=3.942
# Temp=16.50°C | Wind=9.4 km/h | Pred=16.24°C | MAE=3.925
# Temp=16.50°C | Wind=9.4 km/h | Pred=16.25°C | MAE=3.907
# Temp=16.50°C | Wind=9.4 km/h | Pred=16.25°C | MAE=3.889
# Temp=16.50°C | Wind=9.4 km/h | Pred=16.26°C | MAE=3.872
# Temp=16.50°C | Wind=9.4 km/h | Pred=16.26°C | MAE=3.855
# Temp=16.50°C | Wind=9.4 km/h | Pred=16.27°C | MAE=3.838
# Temp=16.50°C | Wind=9.4 km/h | Pred=16.27°C | MAE=3.821
# Temp=16.50°C | Wind=9.4 km/h | Pred=16.28°C | MAE=3.804
# Temp=16.50°C | Wind=9.4 km/h | Pred=16.28°C | MAE=3.787
# Temp=16.50°C | Wind=9.4 km/h | Pred=16.29°C | MAE=3.771
# Temp=16.50°C | Wind=9.4 km/h | Pred=16.29°C | MAE=3.754
# Temp=16.50°C | Wind=9.4 km/h | Pred=16.29°C | MAE=3.738
# Temp=16.50°C | Wind=9.4 km/h | Pred=16.30°C | MAE=3.722
# Temp=16.50°C | Wind=9.4 km/h | Pred=16.30°C | MAE=3.706
# Temp=16.50°C | Wind=9.4 km/h | Pred=16.31°C | MAE=3.690
# Temp=16.50°C | Wind=9.4 km/h | Pred=16.31°C | MAE=3.674
# Temp=16.50°C | Wind=9.4 km/h | Pred=16.31°C | MAE=3.659
# Temp=16.50°C | Wind=9.4 km/h | Pred=16.32°C | MAE=3.643
# Temp=16.50°C | Wind=9.4 km/h | Pred=16.32°C | MAE=3.628
# Temp=16.50°C | Wind=9.4 km/h | Pred=16.32°C | MAE=3.612
# Temp=16.50°C | Wind=9.4 km/h | Pred=16.33°C | MAE=3.597
# Temp=16.50°C | Wind=9.4 km/h | Pred=16.33°C | MAE=3.582
# Temp=16.50°C | Wind=9.4 km/h | Pred=16.34°C | MAE=3.567
# Temp=16.50°C | Wind=9.4 km/h | Pred=16.34°C | MAE=3.553
# Temp=16.50°C | Wind=9.4 km/h | Pred=16.34°C | MAE=3.538
# Temp=16.50°C | Wind=9.4 km/h | Pred=16.34°C | MAE=3.523
# Temp=16.50°C | Wind=9.4 km/h | Pred=16.35°C | MAE=3.509
# Temp=16.50°C | Wind=9.4 km/h | Pred=16.35°C | MAE=3.494
# Temp=16.50°C | Wind=9.4 km/h | Pred=16.35°C | MAE=3.480
# Temp=16.50°C | Wind=9.4 km/h | Pred=16.36°C | MAE=3.466
# Temp=16.50°C | Wind=9.4 km/h | Pred=16.36°C | MAE=3.452
# Temp=16.50°C | Wind=9.4 km/h | Pred=16.36°C | MAE=3.438
# Temp=16.50°C | Wind=9.4 km/h | Pred=16.37°C | MAE=3.424
# Temp=16.50°C | Wind=9.4 km/h | Pred=16.37°C | MAE=3.411
# Temp=16.50°C | Wind=9.4 km/h | Pred=16.37°C | MAE=3.397
# Temp=16.50°C | Wind=9.4 km/h | Pred=16.37°C | MAE=3.383
#
# Stopped streaming.

# %% [markdown]
# # Linear Regressuib (SGD) with ADWIN Drift Detector

# %%
import requests, time
from river import linear_model, optim, preprocessing, metrics, drift

# --- Model Setup ---
model = preprocessing.StandardScaler() | linear_model.LinearRegression(
    optimizer=optim.SGD(0.01)
)
mae = metrics.MAE()

# --- Drift Detector ---
adwin = drift.ADWIN(delta=0.002)

URL = "https://api.open-meteo.com/v1/forecast?latitude=48.85&longitude=2.35&current_weather=true"

print("🌦️ Starting online regression with concept drift detection. Press Ctrl+C to stop.\n")

try:
    while True:
        # Fetch current weather data
        response = requests.get(URL)
        data = response.json()["current_weather"]
        temp = data["temperature"]
        wind = data["windspeed"]

        # Define input/output
        x = {"wind": wind}
        y = temp

        # Predict and learn
        y_pred = model.predict_one(x)
        model.learn_one(x, y)

        # Compute error and update detector
        error = abs(y - (y_pred or 0))
        adwin.update(error)
        mae.update(y, y_pred)

        # Check for drift (new API property name)
        drift_flag = "⚠️ Drift Detected!" if adwin.drift_detected else ""
        print(
            f"Temp={y:.2f}°C | Wind={wind:.1f} km/h | Pred={y_pred:.2f}°C "
            f"| MAE={mae.get():.3f} | Error={error:.3f} {drift_flag}"
        )

        # Reset model if drift detected
        if adwin.drift_detected:
            print("🔄 Resetting model due to detected drift...\n")
            model = preprocessing.StandardScaler() | linear_model.LinearRegression(
                optimizer=optim.SGD(0.01)
            )
            adwin = drift.ADWIN(delta=0.002)

        time.sleep(300)  # 5 min delay (API refresh)

except KeyboardInterrupt:
    print("\nStopped streaming.")
# Out:
# 🌦️ Starting online regression with concept drift detection. Press Ctrl+C to stop.
#
# Temp=16.50°C | Wind=9.4 km/h | Pred=0.00°C | MAE=16.500 | Error=16.500
#
# Stopped streaming.

# %% [markdown]
# # River + Evidently integration

# %%
# ============================================================
try:
    import evidently
except ImportError:
    # !pip install evidently==0.5.1 river scikit-learn requests pandas matplotlib

# %%
import time, requests
import pandas as pd
from river import linear_model, optim, preprocessing, metrics, drift
from evidently.report import Report
from evidently import ColumnMapping
from evidently.metric_preset import DataDriftPreset, RegressionPreset
from tracely import init_tracing  # for Evidently Cloud tracing

# --- Evidently Cloud connection ---
tracer_provider = init_tracing(
    address="https://app.evidently.cloud",
    api_key="dG9rbgFHWHjVjJJGn7OGiLb7In9PXF1LjoaGV4mt1uq5pfHhdQBAgH+c4XXx4RuGpJ28iYiB8p4mkAnVAmrMGhCAeoujHR3YOUD6VpFchsPvpjBKtp3nmag8FQP+l3qwGfnWTxDbG+1GnIM=",  # store in env var for security
    project_id="0199b983-1622-7224-a32f-2f608ab8d49e",
    export_name="streaming-weather-trace",
)
tracer = tracer_provider.get_tracer("streaming-weather-trace")


# --- Column mapping for Evidently ---
column_mapping = ColumnMapping()
column_mapping.target = "temperature"
column_mapping.prediction = "prediction"
column_mapping.numerical_features = ["wind"]

# --- River model setup ---
model = preprocessing.StandardScaler() | linear_model.LinearRegression(optimizer=optim.SGD(0.01))
mae = metrics.MAE()
adwin = drift.ADWIN()

# --- Data buffers for Evidently ---
reference_window = []
current_window = []

URL = "https://api.open-meteo.com/v1/forecast?latitude=48.85&longitude=2.35&current_weather=true"

try:
    while True:
        # Fetch live data
        data = requests.get(URL).json()["current_weather"]
        temp = data["temperature"]
        wind = data["windspeed"]

        # Online learning
        x = {"wind": wind}
        y = temp
        y_pred = model.predict_one(x)
        model.learn_one(x, y)
        mae.update(y, y_pred)
        error = abs(y - (y_pred or 0))
        adwin.update(error)

        drift_flag = adwin.drift_detected

        # Print model status
        print(f"Temp={y:.2f}°C | Wind={wind:.1f} km/h | Pred={y_pred:.2f}°C | MAE={mae.get():.3f}")

        # Log trace
        with tracer.start_as_current_span("online_regression") as span:
            span.set_attribute("temperature", float(y))
            span.set_attribute("wind_speed", float(wind))
            span.set_attribute("prediction", float(y_pred or 0.0))
            span.set_attribute("mae", float(mae.get()))
            span.set_attribute("error", float(error))
            span.set_attribute("drift_detected", bool(drift_flag))
            span.set_attribute("timestamp", time.time())

        # Store in current buffer
        current_window.append({
            "temperature": y,
            "wind": wind,
            "prediction": y_pred,
        })

        # Once we collect enough samples, compute Evidently reports
        if len(current_window) >= 5:
            if not reference_window:
                # initialize reference window with first batch
                reference_window = current_window.copy()
                current_window = []
                print("📘 Reference window initialized with 10 samples.\n")
            else:
                # convert to DataFrames
                ref_df = pd.DataFrame(reference_window)
                cur_df = pd.DataFrame(current_window)

                # --- Regression report ---
                regression_report = Report(metrics=[RegressionPreset()], options={"render": {"raw_data": True}})
                regression_report.run(current_data=cur_df, reference_data=ref_df, column_mapping=column_mapping)
                regression_report.save_html("regression_performance.html")
                print("📊 Regression report saved.")

                # --- Data drift report ---
                drift_report = Report(metrics=[DataDriftPreset()], options={"render": {"raw_data": True}})
                drift_report.run(current_data=cur_df, reference_data=ref_df, column_mapping=column_mapping)
                drift_report.save_html("data_drift_report.html")
                print("🌡️ Drift report saved.\n")

                # Slide window forward
                reference_window = current_window.copy()
                current_window = []

        time.sleep(2)  # every minute

except KeyboardInterrupt:
    print("\nStopped streaming.")
# Out:
# WARNING:opentelemetry.trace:Overriding of current TracerProvider is not allowed
# Temp=18.00°C | Wind=2.7 km/h | Pred=0.00°C | MAE=18.000
# Temp=18.00°C | Wind=2.7 km/h | Pred=0.36°C | MAE=17.820
# Temp=18.00°C | Wind=2.7 km/h | Pred=0.71°C | MAE=17.642
# Temp=18.00°C | Wind=2.7 km/h | Pred=1.06°C | MAE=17.467
# Temp=18.00°C | Wind=2.7 km/h | Pred=1.40°C | MAE=17.294
# 📘 Reference window initialized with 10 samples.
#
# Temp=18.00°C | Wind=2.7 km/h | Pred=1.73°C | MAE=17.124
# Temp=18.00°C | Wind=2.7 km/h | Pred=2.05°C | MAE=16.955
# Temp=18.00°C | Wind=2.7 km/h | Pred=2.37°C | MAE=16.789
# Temp=18.00°C | Wind=2.7 km/h | Pred=2.69°C | MAE=16.625
# Temp=18.00°C | Wind=2.7 km/h | Pred=2.99°C | MAE=16.463
# /home/barbon/Python/440MI/venv/lib/python3.12/site-packages/sklearn/metrics/_regression.py:492: FutureWarning:
#
# 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#
# /home/barbon/Python/440MI/venv/lib/python3.12/site-packages/sklearn/metrics/_regression.py:492: FutureWarning:
#
# 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#
# /home/barbon/Python/440MI/venv/lib/python3.12/site-packages/sklearn/metrics/_regression.py:492: FutureWarning:
#
# 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#
# /home/barbon/Python/440MI/venv/lib/python3.12/site-packages/evidently/metrics/regression_performance/utils.py:16: FutureWarning:
#
# DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#
# /home/barbon/Python/440MI/venv/lib/python3.12/site-packages/evidently/metrics/regression_performance/utils.py:21: FutureWarning:
#
# DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#
# /home/barbon/Python/440MI/venv/lib/python3.12/site-packages/sklearn/metrics/_regression.py:492: FutureWarning:
#
# 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#
# /home/barbon/Python/440MI/venv/lib/python3.12/site-packages/evidently/metrics/regression_performance/utils.py:16: FutureWarning:
#
# DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#
# /home/barbon/Python/440MI/venv/lib/python3.12/site-packages/sklearn/metrics/_regression.py:492: FutureWarning:
#
# 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#
# /home/barbon/Python/440MI/venv/lib/python3.12/site-packages/evidently/metrics/regression_performance/utils.py:21: FutureWarning:
#
# DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#
# /home/barbon/Python/440MI/venv/lib/python3.12/site-packages/evidently/metrics/regression_performance/utils.py:16: FutureWarning:
#
# DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#
# /home/barbon/Python/440MI/venv/lib/python3.12/site-packages/evidently/metrics/regression_performance/utils.py:21: FutureWarning:
#
# DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#
# /home/barbon/Python/440MI/venv/lib/python3.12/site-packages/evidently/metrics/regression_performance/utils.py:16: FutureWarning:
#
# DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#
# /home/barbon/Python/440MI/venv/lib/python3.12/site-packages/evidently/metrics/regression_performance/utils.py:21: FutureWarning:
#
# DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
# 📊 Regression report saved.
# 🌡️ Drift report saved.
# /home/barbon/Python/440MI/venv/lib/python3.12/site-packages/numpy/lib/_function_base_impl.py:2920: RuntimeWarning:
#
# invalid value encountered in divide
#
# /home/barbon/Python/440MI/venv/lib/python3.12/site-packages/numpy/lib/_function_base_impl.py:2920: RuntimeWarning:
#
# invalid value encountered in divide
#
# /home/barbon/Python/440MI/venv/lib/python3.12/site-packages/scipy/stats/_stats_py.py:7400: RuntimeWarning:
#
# divide by zero encountered in divide
#
# /home/barbon/Python/440MI/venv/lib/python3.12/site-packages/numpy/lib/_function_base_impl.py:2920: RuntimeWarning:
#
# invalid value encountered in divide
#
# /home/barbon/Python/440MI/venv/lib/python3.12/site-packages/numpy/lib/_function_base_impl.py:2920: RuntimeWarning:
#
# invalid value encountered in divide
#
# /home/barbon/Python/440MI/venv/lib/python3.12/site-packages/scipy/stats/_stats_py.py:7400: RuntimeWarning:
#
# divide by zero encountered in divide
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 97
#      94 drift_report.save_html("data_drift_report.html")
#      95 print("🌡️ Drift report saved.\n")
# ---> 97 regression_report.log_report(tracer,report=regression_report)
#      99 # Slide window forward
#     100 reference_window = current_window.copy()
#
# AttributeError: 'Report' object has no attribute 'log_report'
